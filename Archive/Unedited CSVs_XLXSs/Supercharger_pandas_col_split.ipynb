# %%
#Dependencies and Setup

import pandas as pd

#Import the CSVs

supercharge_loc = "archive/Supercharge_Locations.csv"

super = pd.read_csv(supercharge_loc, encoding='unicode_escape')

super
# Out:
#                                       Supercharger  \
# 0                                     Buellton, CA
# 1                                      Corning, CA
# 2                                      Barstow, CA
# 3                                       Tifton, GA
# 4                                    Roseville, CA
# ...                                            ...
# 5871          Beijing - Haidian B+W Checker, China
# 5872  Cagnes-sur-Mer  Polygone Riviera P2, France
# 5873                          Naarden, Netherlands
# 5874                            Karlskrona, Sweden
# 5875                          Nürburgring, Germany
#
#                                          Street Address            City  \
# 0                                       555 McMurray Rd        Buellton
# 1                                            950 Hwy 99         Corning
# 2                                       2812 Lenwood Rd         Barstow
# ...

# %%
#super['GPS'] = super['GPS'].str.split(',')
super[['Latitude', 'Longitude']] = super['GPS'].str.split(',', expand = True)

# %%
#super = super.explode('GPS')
super
# Out:
#                                       Supercharger  \
# 0                                     Buellton, CA
# 1                                      Corning, CA
# 2                                      Barstow, CA
# 3                                       Tifton, GA
# 4                                    Roseville, CA
# ...                                            ...
# 5871          Beijing - Haidian B+W Checker, China
# 5872  Cagnes-sur-Mer  Polygone Riviera P2, France
# 5873                          Naarden, Netherlands
# 5874                            Karlskrona, Sweden
# 5875                          Nürburgring, Germany
#
#                                          Street Address            City  \
# 0                                       555 McMurray Rd        Buellton
# 1                                            950 Hwy 99         Corning
# 2                                       2812 Lenwood Rd         Barstow
# ...

# %%
super.to_csv('SP1', encoding='utf-8', index = False)
